# %% [markdown]
# # 트리 구현

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# %%
class NodeMgnt:
    def __init__(self, head):
        self.head = head
        
    def insert(self, value):
        self.current_node = self.head
        while True:
            if value < self.current_node.value:
                if self.current_node.left != None:
                    self.current_node = self.current_node.left
                else:
                    self.current_node.left = Node(value)
                    break
            else:
                if self.current_node.right != None:
                    self.current_node = self.current_node.right
                else:
                    self.current_node.right = Node(value)
                    break
                    
    
    def search(self, value):
        self.current_node = self.head
        
        while self.current_node:
            if self.current_node.value == value:
                return True
            else:
                if value < self.current_node.value:
                    self.current_node = self.current_node.left
                else:
                    self.current_node = self.current_node.right
        
        return False
    
    def delete(self, value):
        parent = self.head
        current_node = self.head
        
        while current_node:
            if current_node.value == value:
                break
            else:
                if value < current_node.value:
                    parent = current_node
                    current_node = current_node.left
                else:
                    parent = current_node
                    current_node = current_node.right

        if not current_node:
            print('해당하는 노드가 없습니다')
        else:
            if not current_node.left and not current_node.right:
                print('---')
                if parent.value < value:
                    parent.right = None
                    
                else:
                    parent.left = None
                    
            else:
                if not (current_node.left and current_node.right):
                    if parent.value < value:
                        parent.right = current_node.left or current_node.right
                    else:
                        parent.left = current_node.left or current_node.right
                else:
                    select_parent_node = current_node.right
                    select_node = current_node.right
                    while True:
                        if not select_node.left:
                            break
                        select_parent_node = select_node
                        select_node = select_node.left
                    if select_node.right:
                        select_parent_node.left = select_node.right
                    else:
                        select_parent_node.left = None
                    
                    if parent.value < value:
                        parent.right = select_node
                    else:
                        parent.left = select_node
                    
                    select_node.left = current_node.left
                    select_node.right = current_node.right
            print(f'{value} 값 삭제 완료')

# %%
head = Node(15)
BST = NodeMgnt(head)

# %%
BST.insert(11)
BST.insert(8)
BST.insert(13)
BST.insert(9)
BST.insert(14)
BST.insert(10)

# %%
BST.search(14)

# %%
BST.delete(11)
# Out:
# 11 값 삭제 완료

# %%
class NodeMgnt2:
    def __init__(self, head):
        self.head = head
        
    def traval(self, node):
        if not node:
            return
        
        print(node.value)
        self.traval(node.left)
        self.traval(node.right)
        
    def insert(self, value):
        self.current_node = self.head
        while True:
            print(f'-----, {value}', self.current_node.value)
            if value < self.current_node.value:
                if self.current_node.left != None:
                    self.current_node = self.current_node.left
                else:
                    print(f'insert! : {value}')
                    self.current_node.left = Node(value)
                    break
            else:
                if self.current_node.right != None:
                    self.current_node = self.current_node.right
                else:
                    print(f'insert! : {value}')
                    self.current_node.right = Node(value)
                    break
                    
    
    def search(self, value):
        self.current_node = self.head
        while self.current_node:
            if self.current_node.value == value:
                return True
            elif value < self.current_node.value:
                self.current_node = self.current_node.left
            else:
                self.current_node = self.current_node.right
        return False  
    
    def delete(self, value):
        searched = False
        self.current_node = self.head
        self.parent = self.head
        
        # --- value값인 node 찾기
        while self.current_node:
            if self.current_node.value == value:
                searched = True
                break
            elif value < self.current_node.value:
                self.parent = self.current_node
                self.current_node = self.current_node.left
            else:
                self.parent = self.current_node
                self.current_node = self.current_node.right
        
        if not searched:
            print(f'{value} 노드가 없습니다')
            return
        
        # ---- 삭제 코드 구현 ---
        
        # 1. current node가 leaf 노드일 때
        if self.current_node == None and self.current_node == None:
            if value < self.parent.value:
                self.parent.left = None
            else:
                self.parent.right = None
        
        # 2. current node가 child를 1개 가지고 있을 때
        #      1. child가 left
        #      2. child가 right
        
        elif self.current_node.left != None and self.current_node.right == None:
            if value < self.current_node.value:
                self.parent.left = self.current_node.left
            else:
                self.parent.right = self.current_node.right
        elif self.current_node.left == None and self.current_node.right != None:
            if value < self.parent.value:
                self.parent.left = self.current_node.right
            else:
                self.parent.right = self.current_node.right
        
        # 3. current node가 child를 모두 가지고 있을 때
        else:
            self.change_node = self.current_node.right
            self.change_node_parent = self.current_node.right
            
            while self.change_node.left:
                self.change_node_parent = self.change_node
                self.change_node = self.change_node.left
            
            if self.change_node.right:
                self.change_node_parent.left = self.change_node.right
            else:
                self.change_node_parent.left = None
            
            if value < self.parent.value:
                self.parent.left = self.change_node
            else:
                self.parent.right = self.change_node
                
            self.change_node.right = self.current_node.right
            self.change_node.left = self.current_node.left
                
        print(f'{value} 값 삭제 완료')

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

# %%
head = Node(30)
BST = NodeMgnt2(head)
BST.insert(16)
BST.insert(8)
BST.insert(20)
BST.insert(18)
BST.insert(24)
BST.insert(19)
# Out:
# -----, 16 30
# insert! : 16
# -----, 8 30
# -----, 8 16
# insert! : 8
# -----, 20 30
# -----, 20 16
# insert! : 20
# -----, 18 30
# -----, 18 16
# -----, 18 20
# insert! : 18
# -----, 24 30
# -----, 24 16
# -----, 24 20
# insert! : 24
# -----, 19 30
# -----, 19 16
# -----, 19 20
# -----, 19 18
# insert! : 19

# %%
print('30 : ', BST.search(30))
print('16 : ', BST.search(16))
print('8  : ', BST.search(8))
print('20 : ', BST.search(20))
print('18 : ', BST.search(18))
print('24 : ', BST.search(24))
print('19 : ', BST.search(19))
# Out:
# 30 :  True
# 16 :  True
# 8  :  True
# 20 :  True
# 18 :  True
# 24 :  True
# 19 :  True

# %%
BST.delete(16)
# Out:
# 16 값 삭제 완료

# %%
BST.traval(BST.head)
# Out:
# 30
# 18
# 8
# 20
# 19
# 24

# %%
# 실행 안되는 케이스!
head = Node(15)
BST2 = NodeMgnt2(head)
BST2.insert(11)
BST2.insert(8)
BST2.insert(13)
BST2.insert(9)
BST2.insert(14)
BST2.insert(10)
# Out:
# -----, 11 15
# insert! : 11
# -----, 8 15
# -----, 8 11
# insert! : 8
# -----, 13 15
# -----, 13 11
# insert! : 13
# -----, 9 15
# -----, 9 11
# -----, 9 8
# insert! : 9
# -----, 14 15
# -----, 14 11
# -----, 14 13
# insert! : 14
# -----, 10 15
# -----, 10 11
# -----, 10 8
# -----, 10 9
# insert! : 10

# %%
import random

numbers = [random.randint(0, 100) for _ in range(100)]

# %%
head = Node(500)
bst = NodeMgnt2(head)
for num in numbers:
    bst.insert(num)
# Out:
# -----, 19 500
# insert! : 19
# -----, 98 500
# -----, 98 19
# insert! : 98
# -----, 38 500
# -----, 38 19
# -----, 38 98
# insert! : 38
# -----, 61 500
# -----, 61 19
# -----, 61 98
# -----, 61 38
# insert! : 61
# -----, 2 500
# -----, 2 19
# insert! : 2
# -----, 18 500
# -----, 18 19
# -----, 18 2
# insert! : 18
# -----, 69 500
# -----, 69 19
# -----, 69 98
# -----, 69 38
# -----, 69 61
# insert! : 69
# -----, 77 500
# -----, 77 19
# -----, 77 98
# -----, 77 38
# -----, 77 61
# -----, 77 69
# insert! : 77
# -----, 9 500
# -----, 9 19
# -----, 9 2
# -----, 9 18
# insert! : 9
# -----, 25 500
# -----, 25 19
# -----, 25 98
# -----, 25 38
# insert! : 25
# -----, 24 500
# -----, 24 19
# -----, 24 98
# -----, 24 38
# -----, 24 25
# insert! : 24
# -----, 16 500
# -----, 16 19
# -----, 16 2
# -----, 16 18
# -----, 16 9
# insert! : 16
# -----, 43 500
# -----, 43 19
# -----, 43 98
# -----, 43 38
# -----, 43 61
# insert! : 43
# -----, 88 500
# -----, 88 19
# -----, 88 98
# -----, 88 38
# ...

# %%
for num in numbers:
    if not bst.search(num):
        print(num)
        print('false!')
# Out:
# 38
# false!
# 67
# false!
# 63
# false!
# 73
# false!
# 10
# false!
# 65
# false!
# 63
# false!
# 38
# false!

# %%
delete_nums = []
for i in range(10):
    delete_nums.append(numbers[random.randint(0, 99)])

# %%
for num in delete_nums:
    bst.delete(num)
# Out:
# 72 값 삭제 완료
# 75 값 삭제 완료
# 77 값 삭제 완료
# 53 값 삭제 완료
# 67 값 삭제 완료
# 10 값 삭제 완료
# 41 값 삭제 완료
# 46 값 삭제 완료
# 10 값 삭제 완료
# 38 값 삭제 완료
